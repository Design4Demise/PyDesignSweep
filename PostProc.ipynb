# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('design_sweep_1609192923.csv') #csv with sweep data
df.head()
# Out:
#     Aerofoil     AR  TaperRatio  SparHeight  SparWidth          BatteryMass  \
# 0  Clark - Y  4.000         1.0       0.015      0.018  0.12660228720332348
# 1  Clark - Y  4.125         1.0       0.015      0.016  0.12630371350891367
# 2  Clark - Y  4.250         1.0       0.015      0.016  0.12603553599973394
# 3  Clark - Y  4.375         1.0       0.015      0.016  0.12579328388717442
# 4  Clark - Y  4.500         1.0       0.015      0.016  0.12557337511530936
#
#             MaxStress
# 0  2271769.3723867964
# 1  2595366.7914017923
# 2  2634397.0535795367
# 3   2672857.439128741
# 4  2710772.2043549074

# %%
df = df[df['BatteryMass'] != 'SPAR FAIL']
print(df.shape)
df.head()
# Out:
# (315, 7)
#     Aerofoil     AR  TaperRatio  SparHeight  SparWidth          BatteryMass  \
# 0  Clark - Y  4.000         1.0       0.015      0.018  0.12660228720332348
# 1  Clark - Y  4.125         1.0       0.015      0.016  0.12630371350891367
# 2  Clark - Y  4.250         1.0       0.015      0.016  0.12603553599973394
# 3  Clark - Y  4.375         1.0       0.015      0.016  0.12579328388717442
# 4  Clark - Y  4.500         1.0       0.015      0.016  0.12557337511530936
#
#             MaxStress
# 0  2271769.3723867964
# 1  2595366.7914017923
# 2  2634397.0535795367
# 3   2672857.439128741
# 4  2710772.2043549074

# %%
numeric_cols = ['AR','TaperRatio','SparHeight','SparWidth','BatteryMass','MaxStress']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)

# %%
SF = 1.5
failure_stress = 4.4908e6 / SF 

df['WithinConstraints'] = df['MaxStress'] < failure_stress
df.head()
# Out:
#     Aerofoil     AR  TaperRatio  SparHeight  SparWidth  BatteryMass  \
# 0  Clark - Y  4.000         1.0       0.015      0.018     0.126602
# 1  Clark - Y  4.125         1.0       0.015      0.016     0.126304
# 2  Clark - Y  4.250         1.0       0.015      0.016     0.126036
# 3  Clark - Y  4.375         1.0       0.015      0.016     0.125793
# 4  Clark - Y  4.500         1.0       0.015      0.016     0.125573
#
#       MaxStress  WithinConstraints
# 0  2.271769e+06               True
# 1  2.595367e+06               True
# 2  2.634397e+06               True
# 3  2.672857e+06               True
# 4  2.710772e+06               True

# %%
sorted_df=df.sort_values('BatteryMass', ascending=True)[df['WithinConstraints'] == 1]
# Out:
# C:\Users\paras\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
sorted_df.head(n=20)
# Out:
#            Aerofoil     AR  TaperRatio  SparHeight  SparWidth  BatteryMass  \
# 60   Falcon-56 MkII  5.500         1.0       0.015      0.018     0.102593
# 59   Falcon-56 MkII  5.375         1.0       0.015      0.018     0.102750
# 58   Falcon-56 MkII  5.250         1.0       0.015      0.018     0.102918
# 57   Falcon-56 MkII  5.125         1.0       0.015      0.018     0.103098
# 56   Falcon-56 MkII  5.000         1.0       0.015      0.018     0.103291
# 55   Falcon-56 MkII  4.875         1.0       0.015      0.020     0.103498
# 54   Falcon-56 MkII  4.750         1.0       0.020      0.010     0.103721
# 53   Falcon-56 MkII  4.625         1.0       0.020      0.020     0.103962
# 52   Falcon-56 MkII  4.500         1.0       0.020      0.020     0.104222
# 51   Falcon-56 MkII  4.375         1.0       0.020      0.022     0.104504
# 50   Falcon-56 MkII  4.250         1.0       0.020      0.022     0.104812
# 49   Falcon-56 MkII  4.125         1.0       0.020      0.022     0.105148
# 48   Falcon-56 MkII  4.000         1.0       0.020      0.022     0.105518
# 324      Trainer 60  8.500         1.0       0.015      0.020     0.110042
# 323      Trainer 60  8.375         1.0       0.015      0.020     0.110088
# 322      Trainer 60  8.250         1.0       0.020      0.012     0.110136
# 321      Trainer 60  8.125         1.0       0.020      0.014     0.110185
# 320      Trainer 60  8.000         1.0       0.020      0.018     0.110238
# 319      Trainer 60  7.875         1.0       0.020      0.020     0.110295
# 318      Trainer 60  7.750         1.0       0.020      0.022     0.110355
#
#         MaxStress  WithinConstraints
# 60   2.663886e+06               True
# 59   2.633440e+06               True
# 58   2.602639e+06               True
# 57   2.571468e+06               True
# 56   2.539915e+06               True
# 55   2.257169e+06               True
# 54   2.506548e+06               True
# 53   1.236674e+06               True
# 52   1.219847e+06               True
# 51   1.093442e+06               True
# 50   1.077708e+06               True
# 49   1.061741e+06               True
# 48   1.045530e+06               True
# 324  2.980480e+06               True
# 323  2.958484e+06               True
# 322  2.752802e+06               True
# 321  2.341601e+06               True
# 320  1.807181e+06               True
# 319  1.613707e+06               True
# 318  1.455316e+06               True

# %%
sorted_df['pcdiff'] = 100*(1- sorted_df['BatteryMass']/sorted_df['BatteryMass'][60])
sorted_df.head(30)
# Out:
#            Aerofoil     AR  TaperRatio  SparHeight  SparWidth  BatteryMass  \
# 60   Falcon-56 MkII  5.500         1.0       0.015      0.018     0.102593
# 59   Falcon-56 MkII  5.375         1.0       0.015      0.018     0.102750
# 58   Falcon-56 MkII  5.250         1.0       0.015      0.018     0.102918
# 57   Falcon-56 MkII  5.125         1.0       0.015      0.018     0.103098
# 56   Falcon-56 MkII  5.000         1.0       0.015      0.018     0.103291
# 55   Falcon-56 MkII  4.875         1.0       0.015      0.020     0.103498
# 54   Falcon-56 MkII  4.750         1.0       0.020      0.010     0.103721
# 53   Falcon-56 MkII  4.625         1.0       0.020      0.020     0.103962
# 52   Falcon-56 MkII  4.500         1.0       0.020      0.020     0.104222
# 51   Falcon-56 MkII  4.375         1.0       0.020      0.022     0.104504
# 50   Falcon-56 MkII  4.250         1.0       0.020      0.022     0.104812
# 49   Falcon-56 MkII  4.125         1.0       0.020      0.022     0.105148
# 48   Falcon-56 MkII  4.000         1.0       0.020      0.022     0.105518
# 324      Trainer 60  8.500         1.0       0.015      0.020     0.110042
# 323      Trainer 60  8.375         1.0       0.015      0.020     0.110088
# 322      Trainer 60  8.250         1.0       0.020      0.012     0.110136
# 321      Trainer 60  8.125         1.0       0.020      0.014     0.110185
# 320      Trainer 60  8.000         1.0       0.020      0.018     0.110238
# 319      Trainer 60  7.875         1.0       0.020      0.020     0.110295
# 318      Trainer 60  7.750         1.0       0.020      0.022     0.110355
# 317      Trainer 60  7.625         1.0       0.020      0.022     0.110417
# 316      Trainer 60  7.500         1.0       0.020      0.022     0.110483
# 315      Trainer 60  7.375         1.0       0.020      0.022     0.110552
# 314      Trainer 60  7.250         1.0       0.020      0.022     0.110624
# 313      Trainer 60  7.125         1.0       0.020      0.022     0.110701
# 312      Trainer 60  7.000         1.0       0.020      0.022     0.110781
# 311      Trainer 60  6.875         1.0       0.020      0.024     0.110865
# 310      Trainer 60  6.750         1.0       0.020      0.024     0.110953
# 309      Trainer 60  6.625         1.0       0.020      0.024     0.111046
# 308      Trainer 60  6.500         1.0       0.020      0.024     0.111145
#
#         MaxStress  WithinConstraints    pcdiff
# 60   2.663886e+06               True  0.000000
# 59   2.633440e+06               True -0.153550
# 58   2.602639e+06               True -0.317518
# 57   2.571468e+06               True -0.492912
# 56   2.539915e+06               True -0.680881
# 55   2.257169e+06               True -0.882739
# 54   2.506548e+06               True -1.100003
# 53   1.236674e+06               True -1.334434
# 52   1.219847e+06               True -1.588089
# 51   1.093442e+06               True -1.863398
# 50   1.077708e+06               True -2.163250
# 49   1.061741e+06               True -2.491125
# 48   1.045530e+06               True -2.851260
# 324  2.980480e+06               True -7.261517
# 323  2.958484e+06               True -7.305888
# 322  2.752802e+06               True -7.352354
# 321  2.341601e+06               True -7.401025
# 320  1.807181e+06               True -7.452018
# 319  1.613707e+06               True -7.507604
# 318  1.455316e+06               True -7.565867
# 317  1.443532e+06               True -7.626960
# 316  1.431651e+06               True -7.691045
# 315  1.419671e+06               True -7.758298
# 314  1.407588e+06               True -7.828909
# 313  1.395401e+06               True -7.903083
# 312  1.383106e+06               True -7.981042
# 311  1.256477e+06               True -8.063026
# 310  1.245002e+06               True -8.149297
# 309  1.233420e+06               True -8.240141
# 308  1.221729e+06               True -8.335867
